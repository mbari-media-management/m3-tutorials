// %%
%classpath add mvn org.vegas-viz vegas_2.11 0.3.11


import vegas._
import vegas.render._
import vegas.data.External._
// Out:
// Could not resolve dependencies for:
// org.vegas-viz : vegas_2.11 : 0.3.11 : jar
// <console>:91: error: not found: value vegas
//        import vegas._
//               ^
// <console>:92: error: not found: value vegas
//        import vegas.render._
//               ^
// <console>:93: error: not found: value vegas
//        import vegas.data.External._
//               ^

// %%
//import groovy.json.JsonSlurper

// def displayPlot(text: String): MIMEContainer = {
    
//     //val jsonSlurper = new JsonSlurper()
//     //val json = jsonSlurper.parseText(text)
//     new MIMEContainer("application/vnd.vega.v2+json", text)
// }

implicit val render = vegas.render.ShowHTML(s => display(HTML(s)))

// %%
Vegas("A simple bar chart with embedded data.").
  withData(Seq(
    Map("a" -> "A", "b" -> 28), Map("a" -> "B", "b" -> 55), Map("a" -> "C", "b" -> 43),
    Map("a" -> "D", "b" -> 91), Map("a" -> "E", "b" -> 81), Map("a" -> "F", "b" -> 53),
    Map("a" -> "G", "b" -> 19), Map("a" -> "H", "b" -> 87), Map("a" -> "I", "b" -> 52)
  )).
  encodeX("a", Ordinal).
  encodeY("b", Quantitative).
  mark(Bar).
  show
// Out:
//   <iframe id="frame-vegas-01bd9cc2-95bc-4f97-989e-a11d69298438" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-01bd9cc2-95bc-4f97-989e-a11d69298438'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;a&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;b&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     }
//   },
//   &quot;description&quot; : &quot;A simple bar chart with embedded data.&quot;,
//   &quot;data&quot; : {
//     &quot;values&quot; : [
//       {
//         &quot;a&quot; : &quot;A&quot;,
//         &quot;b&quot; : 28
//       },
//       {
//         &quot;a&quot; : &quot;B&quot;,
//         &quot;b&quot; : 55
//       },
//       {
//         &quot;a&quot; : &quot;C&quot;,
//         &quot;b&quot; : 43
//       },
//       {
//         &quot;a&quot; : &quot;D&quot;,
//         &quot;b&quot; : 91
//       },
//       {
//         &quot;a&quot; : &quot;E&quot;,
//         &quot;b&quot; : 81
//       },
//       {
//         &quot;a&quot; : &quot;F&quot;,
//         &quot;b&quot; : 53
//       },
//       {
//         &quot;a&quot; : &quot;G&quot;,
//         &quot;b&quot; : 19
//       },
//       {
//         &quot;a&quot; : &quot;H&quot;,
//         &quot;b&quot; : 87
//       },
//       {
//         &quot;a&quot; : &quot;I&quot;,
//         &quot;b&quot; : 52
//       }
//     ]
//   }
// }
//    }
//    vg.embed(&quot;#vegas-01bd9cc2-95bc-4f97-989e-a11d69298438&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-01bd9cc2-95bc-4f97-989e-a11d69298438'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("A bar chart showing the US population distribution of age groups in 2000.").
  withURL(Population).
  mark(Bar).
  filter("datum.year == 2000").
  encodeY("age", Ordinal, scale=Scale(bandSize=17)).
  encodeX("people", Quantitative, aggregate=AggOps.Sum, axis=Axis(title="population")).
  show
// Out:
//   <iframe id="frame-vegas-e60b7753-5c5f-4c4d-b5f5-fdd1a161a2f4" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-e60b7753-5c5f-4c4d-b5f5-fdd1a161a2f4'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;axis&quot; : {
//         &quot;title&quot; : &quot;population&quot;
//       },
//       &quot;field&quot; : &quot;people&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;sum&quot;
//     },
//     &quot;y&quot; : {
//       &quot;scale&quot; : {
//         &quot;bandSize&quot; : 17.0
//       },
//       &quot;field&quot; : &quot;age&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     }
//   },
//   &quot;description&quot; : &quot;A bar chart showing the US population distribution of age groups in 2000.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/population.json&quot;
//   },
//   &quot;transform&quot; : {
//     &quot;filter&quot; : &quot;datum.year == 2000&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-e60b7753-5c5f-4c4d-b5f5-fdd1a161a2f4&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-e60b7753-5c5f-4c4d-b5f5-fdd1a161a2f4'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
 val plot = Vegas("Country Pop").
  withData(
    Seq(
      Map("country" -> "USA", "population" -> 314),
      Map("country" -> "UK", "population" -> 64),
      Map("country" -> "DK", "population" -> 80)
    )
  )
  .encodeX("country", Quant)
  .encodeY("population", Quant)
  .mark(Bar)
  .show
// Out:
//   <iframe id="frame-vegas-360a3d4f-7487-47b8-b5d9-380042cd0c56" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-360a3d4f-7487-47b8-b5d9-380042cd0c56'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;country&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;population&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Country Pop&quot;,
//   &quot;data&quot; : {
//     &quot;values&quot; : [
//       {
//         &quot;country&quot; : &quot;USA&quot;,
//         &quot;population&quot; : 314
//       },
//       {
//         &quot;country&quot; : &quot;UK&quot;,
//         &quot;population&quot; : 64
//       },
//       {
//         &quot;country&quot; : &quot;DK&quot;,
//         &quot;population&quot; : 80
//       }
//     ]
//   }
// }
//    }
//    vg.embed(&quot;#vegas-360a3d4f-7487-47b8-b5d9-380042cd0c56&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-360a3d4f-7487-47b8-b5d9-380042cd0c56'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
val plot = Vegas("Country Pop")
  .withData(
    Seq(
      Map("x" -> "10", "y" -> 314),
      Map("x" -> "20", "y" -> 64),
      Map("x" -> "30", "y" -> 80)
    )
  )
  .encodeX("x", Quant)
  .encodeY("y", Quant)
  .mark(Point)
  .show
// Out:
//   <iframe id="frame-vegas-d6a72697-a9c6-4088-b332-729b239ca014" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-d6a72697-a9c6-4088-b332-729b239ca014'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;x&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;y&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Country Pop&quot;,
//   &quot;data&quot; : {
//     &quot;values&quot; : [
//       {
//         &quot;x&quot; : &quot;10&quot;,
//         &quot;y&quot; : 314
//       },
//       {
//         &quot;x&quot; : &quot;20&quot;,
//         &quot;y&quot; : 64
//       },
//       {
//         &quot;x&quot; : &quot;30&quot;,
//         &quot;y&quot; : 80
//       }
//     ]
//   }
// }
//    }
//    vg.embed(&quot;#vegas-d6a72697-a9c6-4088-b332-729b239ca014&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-d6a72697-a9c6-4088-b332-729b239ca014'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
val x = (1 to 30).map(_.toDouble / math.Pi)
val y = x.map(math.sin(_))
val data = x.zip(y).map(v => Map("x" -> v._1, "y" -> v._2))

val plot = Vegas("Country Pop")
  .withData(data)
  .encodeX("x", Quant)
  .encodeY("y", Quant)
  .mark(Point)
  .show
// Out:
//   <iframe id="frame-vegas-a3ff9dd6-3c04-4b06-a482-cefc64a71fa4" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-a3ff9dd6-3c04-4b06-a482-cefc64a71fa4'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;x&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;y&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Country Pop&quot;,
//   &quot;data&quot; : {
//     &quot;values&quot; : [
//       {
//         &quot;x&quot; : 0.3183098861837907,
//         &quot;y&quot; : 0.31296179620778664
//       },
//       {
//         &quot;x&quot; : 0.6366197723675814,
//         &quot;y&quot; : 0.5944807685248221
//       },
//       {
//         &quot;x&quot; : 0.954929658551372,
//         &quot;y&quot; : 0.8162731085894214
//       },
//       {
//         &quot;x&quot; : 1.2732395447351628,
//         &quot;y&quot; : 0.9560556573276295
//       },
//       {
//         &quot;x&quot; : 1.5915494309189535,
//         &quot;y&quot; : 0.9997846620634563
//       },
//       {
//         &quot;x&quot; : 1.909859317102744,
//         &quot;y&quot; : 0.9430667322569474
//       },
//       {
//         &quot;x&quot; : 2.228169203286535,
//         &quot;y&quot; : 0.7916002371658313
//       },
//       {
//         &quot;x&quot; : 2.5464790894703255,
//         &quot;y&quot; : 0.560602798839214
//       },
//       {
//         &quot;x&quot; : 2.864788975654116,
//         &quot;y&quot; : 0.27328239940311877
//       },
//       {
//         &quot;x&quot; : 3.183098861837907,
//         &quot;y&quot; : -0.0414942916985869
//       },
//       {
//         &quot;x&quot; : 3.5014087480216975,
//         &quot;y&quot; : -0.3521021106818439
//       },
//       {
//         &quot;x&quot; : 3.819718634205488,
//         &quot;y&quot; : -0.6273347343796659
//       },
//       {
//         &quot;x&quot; : 4.138028520389279,
//         &quot;y&quot; : -0.8395399348818634
//       },
//       {
//         &quot;x&quot; : 4.45633840657307,
//         &quot;y&quot; : -0.9673977593093892
//       },
//       {
//         &quot;x&quot; : 4.7746482927568605,
//         &quot;y&quot; : -0.9980625149762887
//       },
//       {
//         &quot;x&quot; : 5.092958178940651,
//         &quot;y&quot; : -0.9284533577547156
//       },
//       {
//         &quot;x&quot; : 5.411268065124442,
//         &quot;y&quot; : -0.7655638200764951
//       },
//       {
//         &quot;x&quot; : 5.729577951308232,
//         &quot;y&quot; : -0.5257591807357896
//       },
//       {
//         &quot;x&quot; : 6.047887837492023,
//         &quot;y&quot; : -0.23313226874348783
//       },
//       {
//         &quot;x&quot; : 6.366197723675814,
//         &quot;y&quot; : 0.08291710873238416
//       },
//       {
//         &quot;x&quot; : 6.684507609859605,
//         &quot;y&quot; : 0.3906359229286669
//       },
//       {
//         &quot;x&quot; : 7.002817496043395,
//         &quot;y&quot; : 0.6591081048558398
//       },
//       {
//         &quot;x&quot; : 7.321127382227186,
//         &quot;y&quot; : 0.8613606385158188
//       },
//       {
//         &quot;x&quot; : 7.639437268410976,
//         &quot;y&quot; : 0.9770735012272838
//       },
//       {
//         &quot;x&quot; : 7.957747154594767,
//         &quot;y&quot; : 0.9946211872313283
//       },
//       {
//         &quot;x&quot; : 8.276057040778557,
//         &quot;y&quot; : 0.9122407056217109
//       },
//       {
//         &quot;x&quot; : 8.594366926962348,
//         &quot;y&quot; : 0.738208705518782
//       },
//       {
//         &quot;x&quot; : 8.91267681314614,
//         &quot;y&quot; : 0.49000993297428647
//       },
//       {
//         &quot;x&quot; : 9.23098669932993,
//         &quot;y&quot; : 0.19258056355208322
//       },
//       {
//         &quot;x&quot; : 9.549296585513721,
//         &quot;y&quot; : -0.12419709955299955
//       }
//     ]
//   }
// }
//    }
//    vg.embed(&quot;#vegas-a3ff9dd6-3c04-4b06-a482-cefc64a71fa4&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-a3ff9dd6-3c04-4b06-a482-cefc64a71fa4'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas().
  withURL(Population).
  mark(Bar).
  addTransformCalculation("gender", """datum.sex == 2 ? "Female" : "Male"""").
  filter("datum.year == 2000").
  encodeColumn("age", Ord, scale=Scale(padding=4.0), axis=Axis(orient=Orient.Bottom, axisWidth=1.0, offset= -8.0)).
  encodeY("people", Quantitative, aggregate=AggOps.Sum, axis=Axis(title="population", grid=false)).
  encodeX("gender", Nominal, scale=Scale(bandSize = 6.0), hideAxis=true).
  encodeColor("gender", Nominal, scale=Scale(rangeNominals=List("#EA98D2", "#659CCA"))).
  configFacet(cell=CellConfig(strokeWidth = 0)).
  show
// Out:
//   <iframe id="frame-vegas-3d70eab4-c16d-4a6c-8461-4f57380ae899" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-3d70eab4-c16d-4a6c-8461-4f57380ae899'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;column&quot; : {
//       &quot;axis&quot; : {
//         &quot;orient&quot; : &quot;bottom&quot;,
//         &quot;axisWidth&quot; : 1.0,
//         &quot;offset&quot; : -8.0
//       },
//       &quot;scale&quot; : {
//         &quot;padding&quot; : 4.0
//       },
//       &quot;field&quot; : &quot;age&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     },
//     &quot;x&quot; : {
//       &quot;axis&quot; : false,
//       &quot;scale&quot; : {
//         &quot;bandSize&quot; : 6.0
//       },
//       &quot;field&quot; : &quot;gender&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     },
//     &quot;y&quot; : {
//       &quot;axis&quot; : {
//         &quot;title&quot; : &quot;population&quot;,
//         &quot;grid&quot; : false
//       },
//       &quot;field&quot; : &quot;people&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;sum&quot;
//     },
//     &quot;color&quot; : {
//       &quot;scale&quot; : {
//         &quot;range&quot; : [
//           &quot;#EA98D2&quot;,
//           &quot;#659CCA&quot;
//         ]
//       },
//       &quot;field&quot; : &quot;gender&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/population.json&quot;
//   },
//   &quot;transform&quot; : {
//     &quot;filter&quot; : &quot;datum.year == 2000&quot;,
//     &quot;calculate&quot; : [
//       {
//         &quot;field&quot; : &quot;gender&quot;,
//         &quot;expr&quot; : &quot;datum.sex == 2 ? \&quot;Female\&quot; : \&quot;Male\&quot;&quot;
//       }
//     ]
//   },
//   &quot;config&quot; : {
//     &quot;facet&quot; : {
//       &quot;cell&quot; : {
//         &quot;strokeWidth&quot; : 0.0
//       }
//     }
//   }
// }
//    }
//    vg.embed(&quot;#vegas-3d70eab4-c16d-4a6c-8461-4f57380ae899&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-3d70eab4-c16d-4a6c-8461-4f57380ae899'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas().
  withURL(Unemployment).
  mark(Area).
  encodeX("date", Temp, timeUnit=TimeUnit.Yearmonth, scale=Scale(nice=Nice.Month),
    axis=Axis(axisWidth=0, format="%Y", labelAngle=0)).
  encodeY("count", Quantitative, aggregate=AggOps.Sum).
  configCell(width=300, height=200).
  show
// Out:
//   <iframe id="frame-vegas-a1d79754-63c0-46b1-90e7-77fa6603def4" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-a1d79754-63c0-46b1-90e7-77fa6603def4'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;area&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;axis&quot; : {
//         &quot;labelAngle&quot; : 0.0,
//         &quot;format&quot; : &quot;%Y&quot;,
//         &quot;axisWidth&quot; : 0.0
//       },
//       &quot;scale&quot; : {
//         &quot;nice&quot; : &quot;month&quot;
//       },
//       &quot;field&quot; : &quot;date&quot;,
//       &quot;type&quot; : &quot;temporal&quot;,
//       &quot;timeUnit&quot; : &quot;yearmonth&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;count&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;sum&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/unemployment-across-industries.json&quot;
//   },
//   &quot;config&quot; : {
//     &quot;cell&quot; : {
//       &quot;width&quot; : 300.0,
//       &quot;height&quot; : 200.0
//     }
//   }
// }
//    }
//    vg.embed(&quot;#vegas-a1d79754-63c0-46b1-90e7-77fa6603def4&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-a1d79754-63c0-46b1-90e7-77fa6603def4'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas().
  withURL(Population).
  filter("datum.year == 2000").
  addTransform("gender", "datum.sex == 2 ? \"Female\" : \"Male\"").
  mark(Bar).
  encodeY("people", Quant, AggOps.Sum, axis=Axis(title="population")).
  encodeX("age", Ord, scale=Scale(bandSize= 17)).
  encodeColor("gender", Nominal, scale=Scale(rangeNominals=List("#EA98D2", "#659CCA"))).
  configMark(stacked=StackOffset.Normalize).
  show
// Out:
//   <iframe id="frame-vegas-8f3a2103-b472-4330-aa36-bddc1766a25d" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-8f3a2103-b472-4330-aa36-bddc1766a25d'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;scale&quot; : {
//         &quot;bandSize&quot; : 17.0
//       },
//       &quot;field&quot; : &quot;age&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     },
//     &quot;y&quot; : {
//       &quot;axis&quot; : {
//         &quot;title&quot; : &quot;population&quot;
//       },
//       &quot;field&quot; : &quot;people&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;sum&quot;
//     },
//     &quot;color&quot; : {
//       &quot;scale&quot; : {
//         &quot;range&quot; : [
//           &quot;#EA98D2&quot;,
//           &quot;#659CCA&quot;
//         ]
//       },
//       &quot;field&quot; : &quot;gender&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/population.json&quot;
//   },
//   &quot;transform&quot; : {
//     &quot;filter&quot; : &quot;datum.year == 2000&quot;,
//     &quot;calculate&quot; : [
//       {
//         &quot;field&quot; : &quot;gender&quot;,
//         &quot;expr&quot; : &quot;datum.sex == 2 ? \&quot;Female\&quot; : \&quot;Male\&quot;&quot;
//       }
//     ]
//   },
//   &quot;config&quot; : {
//     &quot;mark&quot; : {
//       &quot;stacked&quot; : &quot;normalize&quot;
//     }
//   }
// }
//    }
//    vg.embed(&quot;#vegas-8f3a2103-b472-4330-aa36-bddc1766a25d&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-8f3a2103-b472-4330-aa36-bddc1766a25d'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas().
  withURL(Movies).
  mark(Point).
  encodeX("IMDB_Rating", Quantitative, bin=Bin(maxbins=10.0)).
  encodeY("Rotten_Tomatoes_Rating", Quantitative, bin=Bin(maxbins=10.0)).
  encodeSize(aggregate=AggOps.Count, field="*", dataType=Quantitative).
  show
// Out:
//   <iframe id="frame-vegas-3506577a-0aec-4399-9169-92d04534bf53" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-3506577a-0aec-4399-9169-92d04534bf53'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;IMDB_Rating&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : {
//         &quot;maxbins&quot; : 10.0
//       }
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Rotten_Tomatoes_Rating&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : {
//         &quot;maxbins&quot; : 10.0
//       }
//     },
//     &quot;size&quot; : {
//       &quot;field&quot; : &quot;*&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;count&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/movies.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-3506577a-0aec-4399-9169-92d04534bf53&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-3506577a-0aec-4399-9169-92d04534bf53'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("A trellis scatterplot showing Horsepower and Miles per gallons, faceted by binned values of Acceleration.").
  withURL(Cars).
  mark(Point).
  encodeX("Horsepower", Quantitative).
  encodeY("Miles_per_Gallon", Quantitative).
  encodeRow("Acceleration", Quantitative, enableBin=true).
  show
// Out:
//   <iframe id="frame-vegas-71e84668-617a-490b-9e6c-38dab2899998" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-71e84668-617a-490b-9e6c-38dab2899998'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;row&quot; : {
//       &quot;field&quot; : &quot;Acceleration&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : true
//     },
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     }
//   },
//   &quot;description&quot; : &quot;A trellis scatterplot showing Horsepower and Miles per gallons, faceted by binned values of Acceleration.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-71e84668-617a-490b-9e6c-38dab2899998&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-71e84668-617a-490b-9e6c-38dab2899998'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas().
  withURL(Cars).
  mark(Point).
  encodeX("Horsepower", Quantitative).
  encodeY("Miles_per_Gallon", Quantitative).
  encodeColor(field="Origin", dataType=Nominal).
  show
// Out:
//   <iframe id="frame-vegas-e80e6bdb-97e2-40b2-938f-c9586ef17cad" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-e80e6bdb-97e2-40b2-938f-c9586ef17cad'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;color&quot; : {
//       &quot;field&quot; : &quot;Origin&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-e80e6bdb-97e2-40b2-938f-c9586ef17cad&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-e80e6bdb-97e2-40b2-938f-c9586ef17cad'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("A scatterplot showing horsepower and miles per gallons with binned acceleration on color.").
  withURL(Cars).
  mark(Point).
  encodeX("Horsepower", Quantitative).
  encodeY("Miles_per_Gallon", Quantitative).
  encodeColor(field="Acceleration", dataType=Quantitative, bin=Bin(maxbins=5.0)).
  show
// Out:
//   <iframe id="frame-vegas-6b6ef3b6-d991-402a-b478-efd6d4840ae4" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-6b6ef3b6-d991-402a-b478-efd6d4840ae4'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;color&quot; : {
//       &quot;field&quot; : &quot;Acceleration&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : {
//         &quot;maxbins&quot; : 5.0
//       }
//     }
//   },
//   &quot;description&quot; : &quot;A scatterplot showing horsepower and miles per gallons with binned acceleration on color.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-6b6ef3b6-d991-402a-b478-efd6d4840ae4&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-6b6ef3b6-d991-402a-b478-efd6d4840ae4'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas().
  withURL(Cars).
  mark(Area).
  encodeX("Acceleration", Quantitative, bin=Bin()).
  encodeY("Horsepower", Quantitative, AggOps.Mean, enableBin=false).
  encodeColor(field="Cylinders", dataType=Nominal).
  show
// Out:
//   <iframe id="frame-vegas-de6b0445-b816-436e-833b-de625e58e74b" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-de6b0445-b816-436e-833b-de625e58e74b'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;area&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Acceleration&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : {
//
//       }
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : false,
//       &quot;aggregate&quot; : &quot;mean&quot;
//     },
//     &quot;color&quot; : {
//       &quot;field&quot; : &quot;Cylinders&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-de6b0445-b816-436e-833b-de625e58e74b&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-de6b0445-b816-436e-833b-de625e58e74b'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("The Trellis display by Becker et al. helped establish small multiples as a “powerful mechanism for understanding interactions in studies of how a response depends on explanatory variables”. Here we reproduce a trellis of Barley yields from the 1930s, complete with main-effects ordering to facilitate comparison.").
  withURL(Barley).
  mark(Point).
  encodeRow("site", Ordinal).
  encodeX("yield", Quantitative, aggregate=AggOps.Mean).
  encodeY("variety", Ordinal, sortField=Sort("yield", AggOps.Mean), scale=Scale(bandSize = 12.0)).
  encodeColor(field="year", dataType=Nominal).
  show
// Out:
//   <iframe id="frame-vegas-32b89aad-c256-46b0-b7ec-7a14b9fab7a0" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-32b89aad-c256-46b0-b7ec-7a14b9fab7a0'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;row&quot; : {
//       &quot;field&quot; : &quot;site&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     },
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;yield&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;mean&quot;
//     },
//     &quot;y&quot; : {
//       &quot;scale&quot; : {
//         &quot;bandSize&quot; : 12.0
//       },
//       &quot;sort&quot; : {
//         &quot;field&quot; : &quot;yield&quot;,
//         &quot;op&quot; : &quot;mean&quot;
//       },
//       &quot;field&quot; : &quot;variety&quot;,
//       &quot;type&quot; : &quot;ordinal&quot;
//     },
//     &quot;color&quot; : {
//       &quot;field&quot; : &quot;year&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;description&quot; : &quot;The Trellis display by Becker et al. helped establish small multiples as a “powerful mechanism for understanding interactions in studies of how a response depends on explanatory variables”. Here we reproduce a trellis of Barley yields from the 1930s, complete with main-effects ordering to facilitate comparison.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/barley.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-32b89aad-c256-46b0-b7ec-7a14b9fab7a0&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-32b89aad-c256-46b0-b7ec-7a14b9fab7a0'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("A scatterplot with custom star shapes.").
  withURL(Cars).
  mark(Point).
  encodeX("Horsepower", Quant).
  encodeY("Miles_per_Gallon", Quant).
  encodeColor("Cylinders", Nom).
  encodeSize("Weight_in_lbs", Quant).
  configMark(customShape="M0,0.2L0.2351,0.3236 0.1902,0.0618 0.3804,-0.1236 0.1175,-0.1618 0,-0.4 -0.1175,-0.1618 -0.3804,-0.1236 -0.1902,0.0618 -0.2351,0.3236 0,0.2Z").
  show
// Out:
//   <iframe id="frame-vegas-7a2af9a4-9746-486b-a0ab-33c7cb604eac" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-7a2af9a4-9746-486b-a0ab-33c7cb604eac'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;color&quot; : {
//       &quot;field&quot; : &quot;Cylinders&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     },
//     &quot;size&quot; : {
//       &quot;field&quot; : &quot;Weight_in_lbs&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     }
//   },
//   &quot;description&quot; : &quot;A scatterplot with custom star shapes.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   },
//   &quot;config&quot; : {
//     &quot;mark&quot; : {
//       &quot;shape&quot; : &quot;M0,0.2L0.2351,0.3236 0.1902,0.0618 0.3804,-0.1236 0.1175,-0.1618 0,-0.4 -0.1175,-0.1618 -0.3804,-0.1236 -0.1902,0.0618 -0.2351,0.3236 0,0.2Z&quot;
//     }
//   }
// }
//    }
//    vg.embed(&quot;#vegas-7a2af9a4-9746-486b-a0ab-33c7cb604eac&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-7a2af9a4-9746-486b-a0ab-33c7cb604eac'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("A scatterplot showing average horsepower and displacement for cars from different origins.").
  withURL(Cars).
  mark(Point).
  encodeX("Horsepower", Quant, AggOps.Mean).
  encodeY("Displacement", Quant, AggOps.Mean).
  encodeDetail("Origin").
  show
// Out:
//   <iframe id="frame-vegas-b85d2b3a-10e2-459b-98f4-c8aae52ba124" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-b85d2b3a-10e2-459b-98f4-c8aae52ba124'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;mean&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Displacement&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;mean&quot;
//     },
//     &quot;detail&quot; : {
//       &quot;field&quot; : &quot;Origin&quot;
//     }
//   },
//   &quot;description&quot; : &quot;A scatterplot showing average horsepower and displacement for cars from different origins.&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-b85d2b3a-10e2-459b-98f4-c8aae52ba124&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-b85d2b3a-10e2-459b-98f4-c8aae52ba124'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("Stock prices of 5 Tech Companies Over Time.").
  withURL(Stocks, formatType = DataFormat.Csv).
  mark(Line).
  encodeX("date", Temp).
  encodeY("price", Quant).
  encodeDetailFields(Field(field="symbol", dataType=Nominal)).
  show
// Out:
//   <iframe id="frame-vegas-8c613199-1660-45ba-89cf-a6d6f0fff7f0" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-8c613199-1660-45ba-89cf-a6d6f0fff7f0'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;line&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;date&quot;,
//       &quot;type&quot; : &quot;temporal&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;price&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;detail&quot; : {
//       &quot;field&quot; : &quot;symbol&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Stock prices of 5 Tech Companies Over Time.&quot;,
//   &quot;data&quot; : {
//     &quot;format&quot; : {
//       &quot;type&quot; : &quot;csv&quot;
//     },
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/stocks.csv&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-8c613199-1660-45ba-89cf-a6d6f0fff7f0&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-8c613199-1660-45ba-89cf-a6d6f0fff7f0'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("Plot with hard-coded size value").
  withURL(Cars).
  mark(Circle).
  encodeY("Horsepower", Quantitative).
  encodeX("Miles_per_Gallon", Quantitative).
  encodeSize(value=201L).
  show
// Out:
//   <iframe id="frame-vegas-2e5d708e-9104-4284-919c-3177e1cabfda" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-2e5d708e-9104-4284-919c-3177e1cabfda'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;circle&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;size&quot; : {
//       &quot;value&quot; : 201.0
//     }
//   },
//   &quot;description&quot; : &quot;Plot with hard-coded size value&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-2e5d708e-9104-4284-919c-3177e1cabfda&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-2e5d708e-9104-4284-919c-3177e1cabfda'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("Plot with hard-coded size value")
  .withURL(Cars)
  .mark(Circle)
  .encodeY("Horsepower", Quantitative)
  .encodeX("Miles_per_Gallon", Quantitative)
  .encodeSize(value=10L)
  .show
// Out:
//   <iframe id="frame-vegas-baf89738-2348-440f-aad6-369b87fe80f2" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-baf89738-2348-440f-aad6-369b87fe80f2'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;circle&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;size&quot; : {
//       &quot;value&quot; : 10.0
//     }
//   },
//   &quot;description&quot; : &quot;Plot with hard-coded size value&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-baf89738-2348-440f-aad6-369b87fe80f2&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-baf89738-2348-440f-aad6-369b87fe80f2'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas.layered("Plots both mean and IQR as a background layer").
  withURL(Population).
  withLayers(
    Layer().
      mark(Line).
      encodeX("age", Ordinal).
      encodeY("people", aggregate=AggOps.Mean),
    Layer().
      mark(Area).
      encodeX("age", Ordinal).
      encodeY("people", aggregate=AggOps.Q1).
      encodeY2("people", aggregate=AggOps.Q3)
  ).
  show
// Out:
//   <iframe id="frame-vegas-989980b6-516b-42fd-93d7-68b5a9a5e321" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-989980b6-516b-42fd-93d7-68b5a9a5e321'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;layers&quot; : [
//     {
//       &quot;mark&quot; : &quot;line&quot;,
//       &quot;encoding&quot; : {
//         &quot;x&quot; : {
//           &quot;field&quot; : &quot;age&quot;,
//           &quot;type&quot; : &quot;ordinal&quot;
//         },
//         &quot;y&quot; : {
//           &quot;field&quot; : &quot;people&quot;,
//           &quot;aggregate&quot; : &quot;mean&quot;
//         }
//       }
//     },
//     {
//       &quot;mark&quot; : &quot;area&quot;,
//       &quot;encoding&quot; : {
//         &quot;x&quot; : {
//           &quot;field&quot; : &quot;age&quot;,
//           &quot;type&quot; : &quot;ordinal&quot;
//         },
//         &quot;y&quot; : {
//           &quot;field&quot; : &quot;people&quot;,
//           &quot;aggregate&quot; : &quot;q1&quot;
//         },
//         &quot;y2&quot; : {
//           &quot;field&quot; : &quot;people&quot;,
//           &quot;aggregate&quot; : &quot;q3&quot;
//         }
//       }
//     }
//   ],
//   &quot;description&quot; : &quot;Plots both mean and IQR as a background layer&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/population.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-989980b6-516b-42fd-93d7-68b5a9a5e321&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-989980b6-516b-42fd-93d7-68b5a9a5e321'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("Plot with legend on the left and a different title ").
  withURL(Cars).
  mark(Point).
  encodeY("Horsepower", Quantitative).
  encodeX("Miles_per_Gallon", Quantitative).
  encodeColor(field="Origin", dataType=Nominal, legend=Legend(orient = "left", title="Place of Origin" )).
  encodeShape(field="Origin", dataType=Nominal, legend=Legend(orient = "left", title="Place of Origin",
    titleColor="red")).
  show
// Out:
//   <iframe id="frame-vegas-be57c4b1-b2cb-44ff-be70-3ba5650b86e0" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-be57c4b1-b2cb-44ff-be70-3ba5650b86e0'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;point&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;color&quot; : {
//       &quot;legend&quot; : {
//         &quot;title&quot; : &quot;Place of Origin&quot;,
//         &quot;orient&quot; : &quot;left&quot;
//       },
//       &quot;field&quot; : &quot;Origin&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     },
//     &quot;shape&quot; : {
//       &quot;legend&quot; : {
//         &quot;title&quot; : &quot;Place of Origin&quot;,
//         &quot;orient&quot; : &quot;left&quot;,
//         &quot;titleColor&quot; : &quot;red&quot;
//       },
//       &quot;field&quot; : &quot;Origin&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Plot with legend on the left and a different title &quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-be57c4b1-b2cb-44ff-be70-3ba5650b86e0&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-be57c4b1-b2cb-44ff-be70-3ba5650b86e0'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("Plot to show Binning options").
  withURL(Movies).
  mark(Bar).
  encodeX("IMDB_Rating", Quantitative, bin=Bin(step=2.0, maxbins=3.0)).
  encodeY(field="*", Quantitative, aggregate=AggOps.Count).
  show
// Out:
//   <iframe id="frame-vegas-85860eae-1545-4a3b-b90f-c6153b31b29c" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-85860eae-1545-4a3b-b90f-c6153b31b29c'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;IMDB_Rating&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : {
//         &quot;step&quot; : 2.0,
//         &quot;maxbins&quot; : 3.0
//       }
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;*&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;count&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Plot to show Binning options&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/movies.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-85860eae-1545-4a3b-b90f-c6153b31b29c&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-85860eae-1545-4a3b-b90f-c6153b31b29c'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("Plot to show Binning options").
  withURL(Movies).
  mark(Bar).
  encodeX("Worldwide_Gross", Quant, bin=Bin(maxbins=20.0), sortOrder=SortOrder.Desc).
  encodeY(field="*", Quant, aggregate=AggOps.Count).
  show
// Out:
//   <iframe id="frame-vegas-6e55fe5d-aa6f-411d-a3c8-55f44838f973" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-6e55fe5d-aa6f-411d-a3c8-55f44838f973'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;sort&quot; : &quot;descending&quot;,
//       &quot;field&quot; : &quot;Worldwide_Gross&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;bin&quot; : {
//         &quot;maxbins&quot; : 20.0
//       }
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;*&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;,
//       &quot;aggregate&quot; : &quot;count&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Plot to show Binning options&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/movies.json&quot;
//   }
// }
//    }
//    vg.embed(&quot;#vegas-6e55fe5d-aa6f-411d-a3c8-55f44838f973&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-6e55fe5d-aa6f-411d-a3c8-55f44838f973'), 1);
//     })(); // IIFE
//   </script>
// null

// %%
Vegas("Plot to show usage of encodeText").
  withURL(Cars).
  addTransform("OriginInitial", "datum.Origin[0]").
  mark(Text).
  encodeX("Horsepower", Quantitative).
  encodeY("Miles_per_Gallon", Quantitative).
  encodeColor(field="Origin", dataType= Nominal).
  encodeText(field="OriginInitial", dataType= Nominal).
  show
// Out:
//   <iframe id="frame-vegas-509103ff-e161-4f26-b553-c572514e6ded" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-509103ff-e161-4f26-b553-c572514e6ded'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;text&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;Horsepower&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;Miles_per_Gallon&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     },
//     &quot;color&quot; : {
//       &quot;field&quot; : &quot;Origin&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     },
//     &quot;text&quot; : {
//       &quot;field&quot; : &quot;OriginInitial&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Plot to show usage of encodeText&quot;,
//   &quot;data&quot; : {
//     &quot;url&quot; : &quot;https://vega.github.io/vega-editor/app/data/cars.json&quot;
//   },
//   &quot;transform&quot; : {
//     &quot;calculate&quot; : [
//       {
//         &quot;field&quot; : &quot;OriginInitial&quot;,
//         &quot;expr&quot; : &quot;datum.Origin[0]&quot;
//       }
//     ]
//   }
// }
//    }
//    vg.embed(&quot;#vegas-509103ff-e161-4f26-b553-c572514e6ded&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-509103ff-e161-4f26-b553-c572514e6ded'), 1);
//     })(); // IIFE
//   </script>
// null
